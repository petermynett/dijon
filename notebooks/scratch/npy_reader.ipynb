# %% [markdown]
# # Read an .npy file
#
# Load a NumPy binary file and inspect shape, dtype, and a sample.

# %%
import numpy as np
from pathlib import Path

base_dir = Path("data/derived")
next_dir = "meter"
file_name = "YTB-002_meter.npy"

npy_path = Path(base_dir, next_dir, file_name)

arr = np.load(npy_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       6 file_name = "YTB-002_meter.npy"
#       8 npy_path = Path(base_dir, next_dir, file_name)
# ---> 10 arr = np.load(npy_path)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dijon/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/derived/meter/YTB-002_meter.npy'

# %%
print("shape:", arr.shape, "  dtype:", arr.dtype)
print("sample:", arr[:10] if arr.size else arr)
